# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import predictor_of_investment_helper_methods as hm

# %%
case = "IEEE118_mod1"
df_utils = hm.get_utils_cm("R&D",20,case)
np_all_util = df_utils.to_numpy().flatten()
plt.plot(np.sort(np_all_util))

# %%
df_utils_FY.GWh.to_numpy()
# Out:
# array([0.29059134, 0.506017  , 0.04792947, ..., 0.13672134, 0.06427886,
#        0.16817958])

# %%
import matplotlib.pyplot as plt
import numpy as np
end_ = 20000
# List of different values to use instead of "R&D"
cms = ["R&D", "OPC","OPT_LB","CHI","HI"]

# Create a new figure
plt.figure(figsize=(10, 6))

# Loop through each department, get the data, and plot it
for cm in cms:
    # Get the data for each department and case
    df_utils = hm.get_utils_cm(cm, 150, case)
    np_all_util = df_utils.to_numpy().flatten()
    
    # Sort in descending order
    sorted_util = -np.sort(-np_all_util)[:end_]
    
    # Plot the sorted data
    plt.plot(sorted_util, label=cm)

# Add the full year 
df_utils_FY = hm.get_utils_FYWOI(case)
np_all_util_FY = df_utils_FY.GWh.to_numpy().flatten()
sorted_util_FY = -np.sort(-np_all_util_FY)[:end_]

plt.plot(sorted_util_FY, label="Full year")

# Add labels, title, and legend
plt.xlabel('Index')
plt.ylabel('Utility')
plt.title(' Utilities for Different Departments')
plt.legend(title="Clustering methood")
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_utils_FY
# Out:
#          Period Scenario             LoadLevel InitialNode FinalNode Circuit
# 0          2030     sc01  01-01 00:00:00+01:00      bus024    bus072    eac1  \
# 1          2030     sc01  01-01 00:00:00+01:00      bus008    bus030    eac1
# 2          2030     sc01  01-01 00:00:00+01:00      bus060    bus061    eac1
# 3          2030     sc01  01-01 00:00:00+01:00      bus059    bus061    eac1
# 4          2030     sc01  01-01 00:00:00+01:00      bus070    bus071    eac1
# ...         ...      ...                   ...         ...       ...     ...
# 1799610    2030     sc01  12-30 23:00:00+01:00      bus027    bus028    eac1
# 1799611    2030     sc01  12-30 23:00:00+01:00      bus076    bus118    eac1
# 1799612    2030     sc01  12-30 23:00:00+01:00      bus045    bus046    eac1
# 1799613    2030     sc01  12-30 23:00:00+01:00      bus038    bus065    eac1
# 1799614    2030     sc01  12-30 23:00:00+01:00      bus043    bus044    eac1
#
#               GWh
# 0        0.290591
# 1        0.506017
# 2        0.047929
# 3        0.156435
# 4        0.368160
# ...           ...
# 1799610  0.033278
# 1799611  0.187561
# 1799612  0.136721
# 1799613  0.064279
# 1799614  0.168180
#
# [1441440 rows x 7 columns]
