# %%
import os
import pandas as pd

# %%
#%% Setting up the path a cases
DirName  = os.getcwd()

CaseName_Base = '9n'
CSV_name = 'oT_Result_NN_Output_'

# %%
_path_0 = os.path.join(DirName, CaseName_Base)

# %%
folder = _path_0+'/3.Out/0.WoParallel'
filenames = os.listdir(f"{folder}")

# %%
filenames
# Out:
# ['oT_Input_Data_3-bus_Network_Existing_Generation_Full.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_1_Node_2_cac1.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_1_Node_2_cac2.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_1_Node_2_cac3.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_1_Node_3_cac1.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_1_Node_3_cac2.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_1_Node_3_cac3.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_2_Node_3_cac1.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_2_Node_3_cac2.csv',
#  'oT_Input_Data_3-bus_Network_Line_In_Node_2_Node_3_cac3.csv',
#  'oT_Output_Data_3-bus_Network_Existing_Generation_Full.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_1_Node_2_cac1.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_1_Node_2_cac2.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_1_Node_2_cac3.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_1_Node_3_cac1.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_1_Node_3_cac2.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_1_Node_3_cac3.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_2_Node_3_cac1.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_2_Node_3_cac2.csv',
#  'oT_Output_Data_3-bus_Network_Line_In_Node_2_Node_3_cac3.csv',
#  'oT_Result_NN_Input_3-bus.csv',
#  'oT_Result_NN_Output_3-bus.csv']

# %%
df_1 = pd.read_csv(_path_0+'/3.Out'+'/0.WoParallel/'+'oT_Output_Data_'+CaseName_Base+'_Network_Existing_Generation_Full'+'.csv')

# %%
dfNetwork = pd.read_csv(_path_0+'/2.Par'+'/'+'oT_Data_Network_'+CaseName_Base+'.csv', index_col=[0,1,2])

# %%
for (ni,nf,cc) in dfNetwork.index:
    if cc != 'eac1' and cc != 'eac2' and cc != 'eac3':
        df = pd.read_csv(_path_0+'/3.Out'+'/0.WoParallel/'+'oT_Output_Data_'+CaseName_Base+'_Network_Line_In_'+ni+'_'+nf+'_'+cc+'.csv')
        print(ni,nf,cc)
        frames = [df_1, df]
        df_1   = pd.concat(frames)
# Out:
# Node_1 Node_2 cac1
# Node_2 Node_3 cac1
# Node_1 Node_3 cac1
# Node_1 Node_2 cac2
# Node_2 Node_3 cac2
# Node_1 Node_3 cac2
# Node_1 Node_2 cac3
# Node_2 Node_3 cac3
# Node_1 Node_3 cac3

# %%
df_1.set_index(['Variable'], inplace=True)

# %%
df = df_1.loc[['vTotalGCost', 'vTotalCCost', 'vTotalECost', 'vTotalRCost']]

# %%
df = df.reset_index()

# %%
table = pd.pivot_table(df, values='Value', index=['Period', 'Scenario', 'LoadLevel'], columns= ['Execution'])

# %%
table
# Out:
# Execution                             Network_Existing_Generation_Full  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                          0.004112
#                 01-01 01:00:00+01:00                          0.004179
#                 01-01 02:00:00+01:00                          0.004235
#                 01-01 03:00:00+01:00                          0.004314
#                 01-01 04:00:00+01:00                          0.004631
# ...                                                                ...
#                 12-30 19:00:00+01:00                          0.004075
#                 12-30 20:00:00+01:00                          0.004007
#                 12-30 21:00:00+01:00                          0.003857
#                 12-30 22:00:00+01:00                          0.003624
#                 12-30 23:00:00+01:00                          0.003602
#
# Execution                             Network_Line_In_Node_1_Node_2_cac1  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004176
#                 01-01 01:00:00+01:00                            0.004243
#                 01-01 02:00:00+01:00                            0.004298
#                 01-01 03:00:00+01:00                            0.004378
#                 01-01 04:00:00+01:00                            0.004697
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004215
#                 12-30 20:00:00+01:00                            0.004148
#                 12-30 21:00:00+01:00                            0.003997
#                 12-30 22:00:00+01:00                            0.003768
#                 12-30 23:00:00+01:00                            0.003746
#
# Execution                             Network_Line_In_Node_1_Node_2_cac2  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004292
#                 01-01 01:00:00+01:00                            0.004329
#                 01-01 02:00:00+01:00                            0.004362
#                 01-01 03:00:00+01:00                            0.004442
#                 01-01 04:00:00+01:00                            0.004762
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004357
#                 12-30 20:00:00+01:00                            0.004289
#                 12-30 21:00:00+01:00                            0.004138
#                 12-30 22:00:00+01:00                            0.003911
#                 12-30 23:00:00+01:00                            0.003889
#
# Execution                             Network_Line_In_Node_1_Node_2_cac3  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004579
#                 01-01 01:00:00+01:00                            0.004616
#                 01-01 02:00:00+01:00                            0.004636
#                 01-01 03:00:00+01:00                            0.004675
#                 01-01 04:00:00+01:00                            0.004956
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004641
#                 12-30 20:00:00+01:00                            0.004573
#                 12-30 21:00:00+01:00                            0.004422
#                 12-30 22:00:00+01:00                            0.004220
#                 12-30 23:00:00+01:00                            0.004213
#
# Execution                             Network_Line_In_Node_1_Node_3_cac1  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004365
#                 01-01 01:00:00+01:00                            0.004432
#                 01-01 02:00:00+01:00                            0.004488
#                 01-01 03:00:00+01:00                            0.004568
#                 01-01 04:00:00+01:00                            0.004850
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004171
#                 12-30 20:00:00+01:00                            0.004115
#                 12-30 21:00:00+01:00                            0.004009
#                 12-30 22:00:00+01:00                            0.003801
#                 12-30 23:00:00+01:00                            0.003779
#
# Execution                             Network_Line_In_Node_1_Node_3_cac2  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004618
#                 01-01 01:00:00+01:00                            0.004685
#                 01-01 02:00:00+01:00                            0.004741
#                 01-01 03:00:00+01:00                            0.004821
#                 01-01 04:00:00+01:00                            0.005103
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004425
#                 12-30 20:00:00+01:00                            0.004369
#                 12-30 21:00:00+01:00                            0.004263
#                 12-30 22:00:00+01:00                            0.004008
#                 12-30 23:00:00+01:00                            0.004016
#
# Execution                             Network_Line_In_Node_1_Node_3_cac3  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.005125
#                 01-01 01:00:00+01:00                            0.005192
#                 01-01 02:00:00+01:00                            0.005248
#                 01-01 03:00:00+01:00                            0.005327
#                 01-01 04:00:00+01:00                            0.005610
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004931
#                 12-30 20:00:00+01:00                            0.004875
#                 12-30 21:00:00+01:00                            0.004769
#                 12-30 22:00:00+01:00                            0.004515
#                 12-30 23:00:00+01:00                            0.004523
#
# Execution                             Network_Line_In_Node_2_Node_3_cac1  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004089
#                 01-01 01:00:00+01:00                            0.004136
#                 01-01 02:00:00+01:00                            0.004192
#                 01-01 03:00:00+01:00                            0.004272
#                 01-01 04:00:00+01:00                            0.004554
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004022
#                 12-30 20:00:00+01:00                            0.003983
#                 12-30 21:00:00+01:00                            0.003905
#                 12-30 22:00:00+01:00                            0.003707
#                 12-30 23:00:00+01:00                            0.003685
#
# Execution                             Network_Line_In_Node_2_Node_3_cac2  \
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004172
#                 01-01 01:00:00+01:00                            0.004208
#                 01-01 02:00:00+01:00                            0.004228
#                 01-01 03:00:00+01:00                            0.004267
#                 01-01 04:00:00+01:00                            0.004511
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004105
#                 12-30 20:00:00+01:00                            0.004066
#                 12-30 21:00:00+01:00                            0.003988
#                 12-30 22:00:00+01:00                            0.003791
#                 12-30 23:00:00+01:00                            0.003768
#
# Execution                             Network_Line_In_Node_2_Node_3_cac3
# Period Scenario LoadLevel
# 2030   sc01     01-01 00:00:00+01:00                            0.004394
#                 01-01 01:00:00+01:00                            0.004429
#                 01-01 02:00:00+01:00                            0.004453
#                 01-01 03:00:00+01:00                            0.004492
#                 01-01 04:00:00+01:00                            0.004652
# ...                                                                  ...
#                 12-30 19:00:00+01:00                            0.004310
#                 12-30 20:00:00+01:00                            0.004278
#                 12-30 21:00:00+01:00                            0.004214
#                 12-30 22:00:00+01:00                            0.004058
#                 12-30 23:00:00+01:00                            0.004051
#
# [8736 rows x 10 columns]

# %%
for (ni,nf,cc) in dfNetwork.index:
    if cc != 'eac1' and cc != 'eac2' and cc != 'eac3':
        a = 'Network_Line_In_'+ni+'_'+nf+'_'+cc
        table[a] = table['Network_Existing_Generation_Full'] - table[a]

# %%
table = table.drop(['Network_Existing_Generation_Full'], axis=1)

# %%
table.plot()
# Out:
# <Axes: xlabel='Period,Scenario,LoadLevel'>

# %%
table.to_csv(_path_0+'/3.Out'+'/'+'oT_LineBenefit_Data_'+CaseName_Base+'.csv')
