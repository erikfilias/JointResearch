# %%
import os
import pandas as pd

# %%
CaseName_Base = 'RTS24'
CaseName_ByStages = CaseName_Base + '_ByStages'
# CaseName_ByStages_1 = CaseName_Base + '_ByStages_OC_fy_1'
# CaseName_ByStages_2 = CaseName_Base + '_ByStages_OC_fy_2'
# CaseName_ByStages_3 = CaseName_Base + '_ByStages_OC_fy_3'
# CaseName_ByStages_4 = CaseName_Base + '_ByStages_OC_fy_4'

# %%
Folder_A = 'A.The_full_year_MILP'
# Folder_B = 'B.Operation_cost'
Folder_D = 'D.Representative_days_based_on_RES_and_Demand'
Folder_E = 'E.Representative_days_based_on_Line_Benefits_OptModel'
Folder_F = 'F.Representative_days_based_on_Line_Benefit_NN_OC_fy_1'
# Folder_G = 'G.Representative_days_based_on_Line_Benefit_NN_OC_fy_2'
# Folder_H = 'H.Representative_days_based_on_Line_Benefit_NN_OC_fy_3'
# Folder_I = 'I.Representative_days_based_on_Line_Benefit_NN_OC_fy_4'

# %%
DirName  = os.getcwd()

# %%
_path_0 = os.path.join(DirName, CaseName_Base)

# %%
def LoadingData(dir, folder, case, cat1, cat2, cat3):
    df = pd.read_csv(os.path.join(dir, folder, case, '3.Out', 'oT_Result_NetworkInvestment_'+case+'.csv'), index_col=[0,1,2,3])
    df['CaseName'] = folder + ' - ' + case
    df['Category1'] = cat1
    df['Category2'] = cat2
    df['Category3'] = cat3
    df = df.set_index('CaseName', append=True)
    return df

# %%
df_A = LoadingData(DirName, Folder_A, CaseName_Base, 'Original', '1.Full Year', '1.OptModel')
# df_B = LoadingData(DirName, Folder_B, CaseName_ByStages)
df_D = LoadingData(DirName, Folder_D, CaseName_ByStages, 'Representative Days', '2.RES and Demand', '1.OptModel')
df_E = LoadingData(DirName, Folder_E, CaseName_ByStages, 'Representative Days', '3.Line Benefits', '1.OptModel')
df_F = LoadingData(DirName, Folder_F, CaseName_ByStages, 'Representative Days', '3.Line Benefits', '2.NN_1')
# df_G = LoadingData(DirName, Folder_G, CaseName_ByStages, 'Representative Days', '3.Line Benefits', '2.NN_2')
# df_H = LoadingData(DirName, Folder_H, CaseName_ByStages, 'Representative Days', '3.Line Benefits', '2.NN_3')
# df_I = LoadingData(DirName, Folder_I, CaseName_ByStages, 'Representative Days', '3.Line Benefits', '2.NN_4')

# %%
# df = pd.concat([df_A, df_D, df_E, df_F, df_G, df_H, df_I], axis=0)
df = pd.concat([df_A, df_D, df_E, df_F], axis=0)

# %%
# select the row Total System Cost of dataframe df
df = df.reset_index()

# %%
df= df[['InitialNode', 'FinalNode', 'Circuit','CaseName','p.u.', 'Category1', 'Category2', 'Category3']]

# %%
# df = df.loc[df['Cost/Payment'] == 'Total          System Cost']

# %%
df = df.loc[df['p.u.'] == 1.0]

# %%
df['Category4'] = df['Category2'] + ' - ' + df['Category3']

# %%
df['Category5'] = df['InitialNode'] + ' - ' + df['FinalNode'] + ' - ' + df['Circuit']

# %%
df = pd.pivot_table(df, values='p.u.', index=['InitialNode', 'FinalNode', 'Circuit', 'CaseName', 'Category1', 'Category2', 'Category3', 'Category4', 'Category5'], aggfunc='sum')

# %%
# import the necessary python packages
import seaborn as sns
import numpy as np

 
# create a bar plot by specifying
# x and y axis and the data to be used.
ax = sns.barplot(x='CaseName', y='p.u.', data=df.reset_index(),
                 errwidth=0)
 
# sns.barplot method will return a list of
# sub methods use containers method to access
# the text label of each bar by passing it
# through the ax.bar_label function use for
# loop to iterate through the list of
# labels and assign each bar to a different
# label.
for i in ax.containers:
    ax.bar_label(i,)
ax.tick_params(axis='x', rotation=90)

# %%
df.reset_index()
# Out:
#    InitialNode FinalNode Circuit  \
# 0        N_115     N_121    cac1
# 1        N_115     N_121    cac1
# 2        N_115     N_121    cac1
# 3        N_115     N_121    cac1
# 4        N_115     N_121    cac2
# 5        N_115     N_121    cac2
# 6        N_115     N_121    cac2
# 7        N_115     N_124    cac1
# 8        N_115     N_124    cac1
# 9        N_115     N_124    cac1
# 10       N_116     N_117    cac1
# 11       N_116     N_117    cac1
# 12       N_116     N_117    cac1
# 13       N_116     N_117    cac1
# 14       N_117     N_118    cac1
# 15       N_117     N_118    cac1
# 16       N_117     N_118    cac1
# 17       N_118     N_121    cac1
# 18       N_118     N_121    cac2
#
#                                              CaseName            Category1  \
# 0                        A.The_full_year_MILP - RTS24             Original
# 1   D.Representative_days_based_on_RES_and_Demand ...  Representative Days
# 2   E.Representative_days_based_on_Line_Benefits_O...  Representative Days
# 3   F.Representative_days_based_on_Line_Benefit_NN...  Representative Days
# 4                        A.The_full_year_MILP - RTS24             Original
# 5   E.Representative_days_based_on_Line_Benefits_O...  Representative Days
# 6   F.Representative_days_based_on_Line_Benefit_NN...  Representative Days
# 7                        A.The_full_year_MILP - RTS24             Original
# 8   E.Representative_days_based_on_Line_Benefits_O...  Representative Days
# 9   F.Representative_days_based_on_Line_Benefit_NN...  Representative Days
# 10                       A.The_full_year_MILP - RTS24             Original
# 11  D.Representative_days_based_on_RES_and_Demand ...  Representative Days
# 12  E.Representative_days_based_on_Line_Benefits_O...  Representative Days
# 13  F.Representative_days_based_on_Line_Benefit_NN...  Representative Days
# 14                       A.The_full_year_MILP - RTS24             Original
# 15  E.Representative_days_based_on_Line_Benefits_O...  Representative Days
# 16  F.Representative_days_based_on_Line_Benefit_NN...  Representative Days
# 17                       A.The_full_year_MILP - RTS24             Original
# 18  F.Representative_days_based_on_Line_Benefit_NN...  Representative Days
#
#            Category2   Category3                      Category4  \
# 0        1.Full Year  1.OptModel       1.Full Year - 1.OptModel
# 1   2.RES and Demand  1.OptModel  2.RES and Demand - 1.OptModel
# 2    3.Line Benefits  1.OptModel   3.Line Benefits - 1.OptModel
# 3    3.Line Benefits      2.NN_1       3.Line Benefits - 2.NN_1
# 4        1.Full Year  1.OptModel       1.Full Year - 1.OptModel
# 5    3.Line Benefits  1.OptModel   3.Line Benefits - 1.OptModel
# 6    3.Line Benefits      2.NN_1       3.Line Benefits - 2.NN_1
# 7        1.Full Year  1.OptModel       1.Full Year - 1.OptModel
# 8    3.Line Benefits  1.OptModel   3.Line Benefits - 1.OptModel
# 9    3.Line Benefits      2.NN_1       3.Line Benefits - 2.NN_1
# 10       1.Full Year  1.OptModel       1.Full Year - 1.OptModel
# 11  2.RES and Demand  1.OptModel  2.RES and Demand - 1.OptModel
# 12   3.Line Benefits  1.OptModel   3.Line Benefits - 1.OptModel
# 13   3.Line Benefits      2.NN_1       3.Line Benefits - 2.NN_1
# 14       1.Full Year  1.OptModel       1.Full Year - 1.OptModel
# 15   3.Line Benefits  1.OptModel   3.Line Benefits - 1.OptModel
# 16   3.Line Benefits      2.NN_1       3.Line Benefits - 2.NN_1
# 17       1.Full Year  1.OptModel       1.Full Year - 1.OptModel
# 18   3.Line Benefits      2.NN_1       3.Line Benefits - 2.NN_1
#
#                Category5  p.u.
# 0   N_115 - N_121 - cac1   1.0
# 1   N_115 - N_121 - cac1   1.0
# 2   N_115 - N_121 - cac1   1.0
# 3   N_115 - N_121 - cac1   1.0
# 4   N_115 - N_121 - cac2   1.0
# 5   N_115 - N_121 - cac2   1.0
# 6   N_115 - N_121 - cac2   1.0
# 7   N_115 - N_124 - cac1   1.0
# 8   N_115 - N_124 - cac1   1.0
# 9   N_115 - N_124 - cac1   1.0
# 10  N_116 - N_117 - cac1   1.0
# 11  N_116 - N_117 - cac1   1.0
# 12  N_116 - N_117 - cac1   1.0
# 13  N_116 - N_117 - cac1   1.0
# 14  N_117 - N_118 - cac1   1.0
# 15  N_117 - N_118 - cac1   1.0
# 16  N_117 - N_118 - cac1   1.0
# 17  N_118 - N_121 - cac1   1.0
# 18  N_118 - N_121 - cac2   1.0

# %%
df['pu'] = df['p.u.']

# %%
import altair as alt

base = alt.Chart(df.reset_index()).encode(
    alt.X("Category4:O").title(''),
    alt.Y("sum(pu):Q").title('Network Investment (p.u.)'),
    alt.Color("Category4:N").title('').legend(None),
    alt.Text("sum(pu):Q", format=".0f"),
).properties(
    width=100,
    height=100
)

alt.layer(
    base.mark_bar(),
    base.mark_text(dy=-10)
).facet(
    alt.Column("Category5:N", title=None)
).configure_facet(spacing=20).resolve_scale(
  x='independent'
)
# Out:
# alt.FacetChart(...)
