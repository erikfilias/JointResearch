# %%
import DataLoading

# %%
sc = "sc01"
period = "2030"
folder = "RTS24_AC_12w"
te_s = 0.1
val_s = 0.2
executions = DataLoading.list_executions(period,sc,folder)
executions
# Out:
# array(['Network_Existing_Generation_Full',
#        'Network_Line_In_N_101_N_102_cac1'], dtype='<U32')

# %%
dfs_in,dfs_out = DataLoading.load_data(folder,executions,period,sc)
# Out:
# Data/input_f_sc01_Network_Existing_Generation_Full_2030.csv
# 1221
# Data/input_f_sc01_Network_Line_In_N_101_N_102_cac1_2030.csv
# 1221

# %%
s = 0
e = 2800
dfs_out[executions[0]].sum(axis=1)[s:e].plot()
dfs_out[executions[1]].sum(axis=1)[s:e].plot()
# Out:
# <Axes: xlabel='LoadLevel'>

# %%
(dfs_out[executions[0]].sum(axis=1)[s:e]-dfs_out[executions[0]].sum(axis=1)[s:e]).plot()
# Out:
# <Axes: xlabel='LoadLevel'>
